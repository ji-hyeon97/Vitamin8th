# %%
import pandas as pd
df = pd.read_csv('movieinfo.csv')

# %% [markdown]
# #문제 1번 풀이
#
# 열별 결측치를 확인하고 결측치를 각 열의 평균값으로 바꿔주세요

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4916 entries, 0 to 4915
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      4897 non-null   object
#  1   director_name              4814 non-null   object
#  2   num_critic_for_reviews     4867 non-null   float64
#  3   duration                   4901 non-null   float64
#  4   director_facebook_likes    4814 non-null   float64
#  5   actor_3_facebook_likes     4893 non-null   float64
#  6   actor_2_name               4903 non-null   object
#  7   actor_1_facebook_likes     4909 non-null   float64
#  8   gross                      4054 non-null   float64
#  9   genres                     4916 non-null   object
#  10  actor_1_name               4909 non-null   object
#  11  movie_title                4916 non-null   object
#  12  num_voted_users            4916 non-null   int64
#  13  cast_total_facebook_likes  4916 non-null   int64
#  14  actor_3_name               4893 non-null   object
#  15  facenumber_in_poster       4903 non-null   float64
#  16  plot_keywords              4764 non-null   object
#  17  movie_imdb_link            4916 non-null   object
#  18  num_user_for_reviews       4895 non-null   float64
#  19  language                   4904 non-null   object
#  20  country                    4911 non-null   object
#  21  content_rating             4616 non-null   object
#  22  budget                     4432 non-null   float64
#  23  title_year                 4810 non-null   float64
#  24  actor_2_facebook_likes     4903 non-null   float64
#  25  imdb_score                 4916 non-null   float64
#  26  aspect_ratio               4590 non-null   float64
#  27  movie_facebook_likes       4916 non-null   int64
# dtypes: float64(13), int64(3), object(12)
# memory usage: 1.1+ MB

# %%
df.isnull().sum()
# Out:
# color                         19
# director_name                102
# num_critic_for_reviews        49
# duration                      15
# director_facebook_likes      102
# actor_3_facebook_likes        23
# actor_2_name                  13
# actor_1_facebook_likes         7
# gross                        862
# genres                         0
# actor_1_name                   7
# movie_title                    0
# num_voted_users                0
# cast_total_facebook_likes      0
# actor_3_name                  23
# facenumber_in_poster          13
# plot_keywords                152
# movie_imdb_link                0
# num_user_for_reviews          21
# language                      12
# country                        5
# content_rating               300
# budget                       484
# title_year                   106
# actor_2_facebook_likes        13
# imdb_score                     0
# aspect_ratio                 326
# movie_facebook_likes           0
# dtype: int64

# %%
df.fillna(df.mean(), inplace=True)
df
# Out:
#       color      director_name  ...  aspect_ratio  movie_facebook_likes
# 0     Color      James Cameron  ...      1.780000                 33000
# 1     Color     Gore Verbinski  ...      2.350000                     0
# 2     Color         Sam Mendes  ...      2.350000                 85000
# 3     Color  Christopher Nolan  ...      2.350000                164000
# 4       NaN        Doug Walker  ...      2.222349                     0
# ...     ...                ...  ...           ...                   ...
# 4911  Color        Scott Smith  ...      2.222349                    84
# 4912  Color                NaN  ...     16.000000                 32000
# 4913  Color   Benjamin Roberds  ...      2.222349                    16
# 4914  Color        Daniel Hsia  ...      2.350000                   660
# 4915  Color           Jon Gunn  ...      1.850000                   456
#
# [4916 rows x 28 columns]

# %%
df.isnull().sum()
# Out:
# color                         19
# director_name                102
# num_critic_for_reviews         0
# duration                       0
# director_facebook_likes        0
# actor_3_facebook_likes         0
# actor_2_name                  13
# actor_1_facebook_likes         0
# gross                          0
# genres                         0
# actor_1_name                   7
# movie_title                    0
# num_voted_users                0
# cast_total_facebook_likes      0
# actor_3_name                  23
# facenumber_in_poster           0
# plot_keywords                152
# movie_imdb_link                0
# num_user_for_reviews           0
# language                      12
# country                        5
# content_rating               300
# budget                         0
# title_year                     0
# actor_2_facebook_likes         0
# imdb_score                     0
# aspect_ratio                   0
# movie_facebook_likes           0
# dtype: int64

# %%
df = df.dropna(how='any')
df
# Out:
#       color      director_name  ...  aspect_ratio  movie_facebook_likes
# 0     Color      James Cameron  ...      1.780000                 33000
# 1     Color     Gore Verbinski  ...      2.350000                     0
# 2     Color         Sam Mendes  ...      2.350000                 85000
# 3     Color  Christopher Nolan  ...      2.350000                164000
# 5     Color     Andrew Stanton  ...      2.350000                 24000
# ...     ...                ...  ...           ...                   ...
# 4907  Color   Neill Dela Llana  ...      2.222349                    74
# 4908  Color   Robert Rodriguez  ...      1.370000                     0
# 4909  Color    Anthony Vallone  ...      2.222349                     4
# 4910  Color       Edward Burns  ...      2.222349                   413
# 4915  Color           Jon Gunn  ...      1.850000                   456
#
# [4460 rows x 28 columns]

# %%
df.isnull().sum()
# Out:
# color                        0
# director_name                0
# num_critic_for_reviews       0
# duration                     0
# director_facebook_likes      0
# actor_3_facebook_likes       0
# actor_2_name                 0
# actor_1_facebook_likes       0
# gross                        0
# genres                       0
# actor_1_name                 0
# movie_title                  0
# num_voted_users              0
# cast_total_facebook_likes    0
# actor_3_name                 0
# facenumber_in_poster         0
# plot_keywords                0
# movie_imdb_link              0
# num_user_for_reviews         0
# language                     0
# country                      0
# content_rating               0
# budget                       0
# title_year                   0
# actor_2_facebook_likes       0
# imdb_score                   0
# aspect_ratio                 0
# movie_facebook_likes         0
# dtype: int64

# %% [markdown]
# #문제 2번 풀이
#
# astype을 이용해 num_critic_for_reviews와 gross열의 데이터타입을 int64로 바꿔주세요

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4460 entries, 0 to 4915
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      4460 non-null   object
#  1   director_name              4460 non-null   object
#  2   num_critic_for_reviews     4460 non-null   float64
#  3   duration                   4460 non-null   float64
#  4   director_facebook_likes    4460 non-null   float64
#  5   actor_3_facebook_likes     4460 non-null   float64
#  6   actor_2_name               4460 non-null   object
#  7   actor_1_facebook_likes     4460 non-null   float64
#  8   gross                      4460 non-null   float64
#  9   genres                     4460 non-null   object
#  10  actor_1_name               4460 non-null   object
#  11  movie_title                4460 non-null   object
#  12  num_voted_users            4460 non-null   int64
#  13  cast_total_facebook_likes  4460 non-null   int64
#  14  actor_3_name               4460 non-null   object
#  15  facenumber_in_poster       4460 non-null   float64
#  16  plot_keywords              4460 non-null   object
#  17  movie_imdb_link            4460 non-null   object
#  18  num_user_for_reviews       4460 non-null   float64
#  19  language                   4460 non-null   object
#  20  country                    4460 non-null   object
#  21  content_rating             4460 non-null   object
#  22  budget                     4460 non-null   float64
#  23  title_year                 4460 non-null   float64
#  24  actor_2_facebook_likes     4460 non-null   float64
#  25  imdb_score                 4460 non-null   float64
#  26  aspect_ratio               4460 non-null   float64
#  27  movie_facebook_likes       4460 non-null   int64
# dtypes: float64(13), int64(3), object(12)
# memory usage: 1010.5+ KB

# %%
df = df.astype({'num_critic_for_reviews': 'int'})
df = df.astype({'gross': 'int'})
print(df.dtypes)
# Out:
# color                         object
# director_name                 object
# num_critic_for_reviews         int64
# duration                     float64
# director_facebook_likes      float64
# actor_3_facebook_likes       float64
# actor_2_name                  object
# actor_1_facebook_likes       float64
# gross                          int64
# genres                        object
# actor_1_name                  object
# movie_title                   object
# num_voted_users                int64
# cast_total_facebook_likes      int64
# actor_3_name                  object
# facenumber_in_poster         float64
# plot_keywords                 object
# movie_imdb_link               object
# num_user_for_reviews         float64
# language                      object
# country                       object
# content_rating                object
# budget                       float64
# title_year                   float64
# actor_2_facebook_likes       float64
# imdb_score                   float64
# aspect_ratio                 float64
# movie_facebook_likes           int64
# dtype: object

# %% [markdown]
# # 문제 3번 풀이
#
# 불린 인덱싱을 통해 num_critic_for reviews 가 500 이상이고 gross가 열의 75% 분위수 이상인 행만 뽑아 df1에 저장해주세요

# %%
df2 = df[(df['num_critic_for_reviews']>=500)]
df2.reset_index()
df2.quantile(0.75)
# Out:
# num_critic_for_reviews       6.450000e+02
# duration                     1.492500e+02
# director_facebook_likes      7.402500e+02
# actor_3_facebook_likes       1.000000e+03
# actor_1_facebook_likes       2.600000e+04
# gross                        2.603179e+08
# num_voted_users              5.249242e+05
# cast_total_facebook_likes    3.946925e+04
# facenumber_in_poster         1.000000e+00
# num_user_for_reviews         1.189250e+03
# budget                       1.757500e+08
# title_year                   2.014000e+03
# actor_2_facebook_likes       1.225000e+04
# imdb_score                   8.000000e+00
# aspect_ratio                 2.350000e+00
# movie_facebook_likes         1.232500e+05
# Name: 0.75, dtype: float64

# %%
df2 = df[(df['num_critic_for_reviews']>=500)]
df2.reset_index()
df1 =df2[(df2['gross']>=2.603179e+08)]
df1
# Out:
#      color      director_name  ...  aspect_ratio  movie_facebook_likes
# 0    Color      James Cameron  ...          1.78                 33000
# 3    Color  Christopher Nolan  ...          2.35                164000
# 8    Color        Joss Whedon  ...          2.35                118000
# 10   Color        Zack Snyder  ...          2.35                197000
# 15   Color        Zack Snyder  ...          2.35                118000
# 17   Color        Joss Whedon  ...          1.85                123000
# 21   Color          Marc Webb  ...          2.35                 56000
# 27   Color      Anthony Russo  ...          2.35                 72000
# 29   Color    Colin Trevorrow  ...          2.00                150000
# 30   Color         Sam Mendes  ...          2.35                 80000
# 32   Color        Shane Black  ...          2.35                 95000
# 66   Color  Christopher Nolan  ...          2.35                 37000
# 78   Color        Pete Docter  ...          1.85                118000
# 95   Color         James Gunn  ...          2.35                 96000
# 97   Color  Christopher Nolan  ...          2.35                175000
# 99   Color      Peter Jackson  ...          2.35                166000
# 185  Color   Francis Lawrence  ...          2.35                 82000
# 243  Color     Alfonso Cuarón  ...          2.35                147000
# 433  Color          Gary Ross  ...          2.35                140000
# 803  Color         Tim Miller  ...          2.35                117000
#
# [20 rows x 28 columns]

# %% [markdown]
# #문제 4번 풀이
#
# df1에서 director_facebook_likes가 가장 높은 영화의 감독 이름을 k라는 변수에 할당해주세요 (method chaining 사용, 인덱스 유의)

# %%
df2 = df.sort_values(by='director_facebook_likes',ascending=False)
k = df2['director_name'].reset_index().at[0,'director_name']
k
# Out:
# 'Joseph Gordon-Levitt'

# %% [markdown]
# #문제 4-1번 풀이
#
# 위의 영화 감독이 만든 영화를 모두 뽑고 그 영화들의 imdb score 평균을 구해주세요 (query 사용, method chaining)

# %%
df = df.query('director_name == "Joseph Gordon-Levitt"')
df['imdb_score'].mean()
# Out:
# 6.6
